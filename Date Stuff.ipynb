# %%
import pandas as pd
import datetime
from finance_app import *

# %%
today = datetime.date.today()
idx = (today.weekday() + 1) % 7 # 0 Indexed from Sunday
last_sun = today - datetime.timedelta(idx)
prev_sun = today - datetime.timedelta(7+idx)
prev_sat = today - datetime.timedelta(7+idx-6)
# Must index by range
prev_sat
# Out:
# datetime.date(2016, 10, 15)

# %%
df.truncate(after=last_sun)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Spencer/Distributions_et_al/anaconda/envs/py35/lib/python3.5/site-packages/pandas/indexes/base.py in get_slice_bound(self, label, side, kind)
#    2909             try:
# -> 2910                 return self._searchsorted_monotonic(label, side)
#    2911             except ValueError:
#
# /Users/Spencer/Distributions_et_al/anaconda/envs/py35/lib/python3.5/site-packages/pandas/indexes/base.py in _searchsorted_monotonic(self, label, side)
#    2875
# -> 2876         raise ValueError('index must be monotonic increasing or decreasing')
#    2877
#
# ValueError: index must be monotonic increasing or decreasing
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-666d3cbcccd7> in <module>()
# ...

# %%
df.truncate(after=prev_sun) # there's some bug as it's still including a 10-02 date (should be after 10-15)
# Out:
#                               Description  \
# Date
# 2016-10-02                  The Last Word
# 2016-10-13  Venmo Cashout Tran - Oct Rent
# 2016-10-13                    Continental
# 2016-10-13                      Mujo Cafe
# 2016-10-12          Tcf Bank- for Aparrel
# 2016-10-12                    Mighty Good
# 2016-10-12                        Aramark
# 2016-10-12                    Continental
# 2016-10-12                       7-Eleven
# 2016-10-12                  Venmo Cashout
# 2016-10-11                      Mujo Cafe
# 2016-10-11                   B S N Sports
# 2016-10-11                      Mujo Cafe
# 2016-10-11                      Mujo Cafe
# 2016-10-11                      Mujo Cafe
# 2016-10-11                  U Go Pierpont
# 2016-10-11                         Amazon
# 2016-10-09                   Comet Coffee
#
#                                          Original Description  Amount  \
# Date
# ...

# %%
# Let's make a date range for each month/week:
weeks = pd.date_range('9/6/16', datetime.date.today(), freq='W' )

# %%
# For last_wk_data(_df) (starting at Last Sunday)
wk_delta = datetime.timedelta(

# %%
# What we want, but with automatically generated dates
df['9/6/16':'9/12/16']
# Out:
#                            Description  \
# Date
# 2016-09-12        Inst Xfer - Evernote
# 2016-09-12                Jimmy John's
# 2016-09-12                Panera Bread
# 2016-09-11                      iTunes
# 2016-09-11                    7-Eleven
# 2016-09-10              Chane Music Ci
# 2016-09-09                   Mujo Cafe
# 2016-09-08    Deposit Pncbank Xtransfr
# 2016-09-08       Penn Station Plymouth
# 2016-09-08                 Planet Rock
# 2016-09-08      Inst Xfer - IM leagues
# 2016-09-07  Prime Student Ho  - chriss
# 2016-09-07            Prime Student Ho
# 2016-09-07                   Mujo Cafe
# 2016-09-07           Airbnb Payments G
# 2016-09-06              Ku Parking Web
# 2016-09-06          Sublette Crct Cour
# 2016-09-06       Altairglob Cwf Altair
# 2016-09-06    Funds Transfer Brokerage
# 2016-09-06    Funds Transfer Brokerage
#
#                                 Original Description   Amount  \
# Date
# ...

# %%
df[months[0]:months[1]]
# Out:
# Empty DataFrame
# Columns: [Description, Original Description, Amount, Transaction Type, Category, Account Name, Labels, Notes]
# Index: []
