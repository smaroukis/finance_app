# %%
import pandas as pd
import datetime
from finance_app import *

# %%
today = datetime.date.today()
idx = (today.weekday() + 1) % 7 # 0 Indexed from Sunday
sun1b4 = today - datetime.timedelta(idx)
sun2b4 = today - datetime.timedelta(7+idx)
sat1b4 = today - datetime.timedelta(7+idx-6)
# Must index by range
# Want dates bn sun2 and sat1
print('sun1=', sun1, 'sun2=', sun2, 'sat1=',sat1)
# Out:
# sun1= 2016-10-30 sun2= 2016-10-23 sat1= 2016-10-29

# %%
lastwk = df.truncate(before=sat1b4)
lastwk = df.truncate(after=sun2b4)

# %%
# Print Results

# Clean: drop hidden
lastwk = lastwk.loc[laswk.Category.isin(expenses)]

# %%
def clean_df(_df, _st, _end, *, labels=None, cats=None, descr=None):
	# labels and categories as list, exact match but descriptions will be transformed to regexp
	df = _df.truncate(before=_end)
	df = df.truncate(after=_st)
	# Make sure "Categories" and "Labels" are in df
	if labels:
		df = df[~df.Labels.isin(labels)]
	if cats:
		df = df[~df.Category.isin(cats)]
	if descr:
		df = df[~df.Description.str.containts('|'.join(descr))]
	return df

clean_df(df, sun2, sat1, labels=['Hide'], cats=['Hide from Budgets & Trends'])
# Out:
#                                    Description  \
# Date
# 2016-10-29                     Espresso Royale
# 2016-10-29                 Lyft - from airport
# 2016-10-29                        Jimmy John's
# 2016-10-28        Venmo - Chris (sushi dinner)
# 2016-10-28              Venmo - Chris (drinks)
# 2016-10-28        Venmo - Chris (parking, gas)
# 2016-10-28                           Mujo Cafe
# 2016-10-28                         Continental
# 2016-10-28                         Continental
# 2016-10-28                   Venmo - Utilities
# 2016-10-27                       Cafeto Coffee
# 2016-10-27                   Blue Bottle Cosan
# 2016-10-27                                Lyft
# 2016-10-27                              iTunes
# 2016-10-27              San Francisco, Ca Rgnl
# 2016-10-27              Venmo - dinner to erik
# 2016-10-27                                BART
# 2016-10-26                      Venmo - Dinner
# 2016-10-26                                Lyft
# ...

# %% [markdown]
# ### Older

# %%
# Let's make a date range for each month/week:
weeks = pd.date_range('9/6/16', datetime.date.today(), freq='W' )

# For last_wk_data(_df) (starting at Last Sunday)
wk_delta = datetime.timedelta(

# What we want, but with automatically generated dates
df['9/6/16':'9/12/16']

df[months[0]:months[1]]
