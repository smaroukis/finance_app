# %%
import pandas as pd
import datetime as dt
import os
import openpyxl

# %%
# Directory of Dropbox connected mint data
og_dir = '/Users/Spencer/Dropbox/2016_expenses (1).xlsx'
ogdf = pd.read_excel(og_dir, parse_dates='Date', index_col = 'Date')
# Directory/Filename of New Data
data_dir = '~/Downloads/transactions.csv'
datadf = pd.read_csv(data_dir, parse_dates='Date', index_col = 'Date')


#now = dt.datetime.today()
#lastweek = now - dt.timedelta(days=7)
#dates = pd.date_range['2016-07-01','2016-07-08']
#start = dt.datetime(2016, 7, 1)
#datadf.ix[start:start + dt.timedelta(days=10)]

# %% [markdown]
# #### Helpful
#  - `ogdf.index.name`
#
#  - `df.set_index('Date', drop=False)` sets the index as Date but also keeps the data in the dataframe
#
#  - `pd.DatetimeIndex(list_of_dates)` to convert to timestamps
#
#  - `datetime(2012, 1, 1)` is a datetime object
#  - `df['2012-11-11']` parses under the hood the index as datetime
#  - `ts.sort_index()` sorts by time if timeindexed

# %%
datadf.truncate(after='07/01/2016')
# Out:
#                            Description  \
# Date
# 2016-07-27    Deposit Pncbank Xtransfr
# 2016-07-27                  Racha Cafe
# 2016-07-27                    Eatsa Ca
# 2016-07-27                      iTunes
# 2016-07-27                        BART
# 2016-07-27    Funds Transfer Brokerage
# 2016-07-27                        Arco
# 2016-07-26                 Cafe Strada
# 2016-07-26                Trader Joe's
# 2016-07-25                      iTunes
# 2016-07-25               Noah's Bagels
# 2016-07-25                    Uber.com
# 2016-07-25              Artichoke Basi
# 2016-07-25                       Venmo
# 2016-07-24              Shattuck Marke
# 2016-07-23               Espresso Roma
# 2016-07-23         Caffe Mediterraneum
# 2016-07-21               Peet's Coffee
# 2016-07-21                   Starbucks
# 2016-07-21               Residence Inn
# 2016-07-21       Altairglob Cwf Altair
# 2016-07-21                        BART
# 2016-07-20                  Metal Mark
# ...

# %%
df = pd.concat([ogdf, datadf])

# %%
df_gpby = df.groupby(list(df.columns))

# %%
idx = [x[0] for x in df_gpby.groups.values() if len(x) == 1]

# %%
df.iloc[idx]
# Out:
#                     Date                  Description  \
# 4    2016-07-04 00:00:00          Great Western Power
# 953  2015-08-26 00:00:00                         Card
# 845  2015-10-06 00:00:00         EECS Vending Machine
# 127  2016-05-31 00:00:00               ATM Fee Refund
# 764  2015-11-04 00:00:00     Deposit Pncbank Xtransfr
# 550  2016-01-29 00:00:00               ATM Fee Refund
# 552  2016-01-29 00:00:00        Hostel World Internet
# 608  2016-01-10 00:00:00                P E Washingto
# 10   2016-07-02 00:00:00                     7-Eleven
# 537  2016-02-02 00:00:00      Account Maintenance Fee
# 575  2016-01-22 00:00:00                    Mujo Cafe
# 689  2015-12-05 00:00:00                       iTunes
# 111  2016-06-04 00:00:00                      Freeway
# 335  2016-04-05 00:00:00                       Amazon
# 926  2015-09-08 00:00:00                        Venmo
# 561  2016-01-25 00:00:00                Venmo Cashout
# ...
